# %% [markdown]
# ![title](imagens/cabec_08g.jpg)

# %% [markdown]
# ## <font color='green'>Projeto 6 - Marketing para Instituições Financeiras - Parte 01</font>
# ## <font color='green'>Instalando os Pacotes e Carregando os Dados</font>

# %% [markdown]
# ## Instalando e Carregando os Pacotes

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python usada neste Projeto no Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python usada neste Projeto no Jupyter Notebook: 3.11.7

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
# !pip install nome_pacote==versão_desejada

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook.

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark

# %%
# Importação dos Pacotes necessários para este projeto
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "pyPRO - Seja um Profissional Python!" --iversions
# Out:
# Author: pyPRO - Seja um Profissional Python!
#
# numpy     : 1.26.4
# matplotlib: 3.8.4
# seaborn   : 0.13.2
# pandas    : 2.2.2

# %% [markdown]
# ## Carregando os Dados

# %% [markdown]
# Neste projeto vamos trabalhar com um *data set modificado* do seguinte repositório:
# **UCI - Machine Learning Repository (Center of Machine Learning and Intelligent Systems)**
# Link: https://archive.ics.uci.edu/ml/datasets/bank+marketing
#
# Trata-se de um data set onde os dados estão relacionados com campanhas de marketing direto de uma instituição bancária portuguesa. As campanhas de marketing foram baseadas em telefonemas. Muitas vezes, era necessário mais do que um contacto para o mesmo cliente, para saber se o produto (depósito bancário a prazo) seria ('sim') ou não ('não') confirmado (subscrito).
#
# Os dados foram modificados para fosse possível realizarmos operações as limpeza de dados que vamos trabalhar neste projeto.
# O data set (arquivo csv pronto para uso) estará disponíveis como recurso dessa aula.

# %%
# Carrega o dataset
df = pd.read_csv("dados/bank-full.csv")

# %%
# Shape
df.shape
# Out:
# (45211, 18)

# %%
# Amostra
df.head()
# Out:
#    id   age           job         maritalEdu    salary  balance default  \
# 0   1  58.0    management   married-tertiary  100000.0     2143      no
# 1   2  44.0    technician   single-secondary   60000.0       29      no
# 2   3  33.0  entrepreneur  married-secondary  120000.0        2      no
# 3   4  47.0   blue-collar    married-unknown   20000.0     1506      no
# 4   5  33.0       unknown     single-unknown       0.0        1      no
#
#   housing loan  contact  day month  duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5   may       261         1     -1         0
# 1     yes   no  unknown    5   may       151         1     -1         0
# 2     yes  yes  unknown    5   may        76         1     -1         0
# 3     yes   no  unknown    5   may        92         1     -1         0
# 4      no   no  unknown    5   may       198         1     -1         0
#
#   poutcome target
# 0  unknown     no
# 1  unknown     no
# 2  unknown     no
# 3  unknown     no
# ...

# %% [markdown]
# ## Fim da Parte 1
